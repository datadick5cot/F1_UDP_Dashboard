# %%
import plotly.graph_objects as go
from codeassets import graph_config, graph_backgrounds, create_loading_figure
import plotly.graph_objects as go

throttleGraph = go.Figure()

yaxis = [0] * 15
xaxis = list(range(1, 16))
size = [20] * 15

throttleGraph.add_trace(go.Scatter(
    x=xaxis,
    y=yaxis,
    mode='markers',
    marker=dict(size=size)
    
))

xaxis=dict(
    showline=False,
    showticklabels=False,
    showgrid=False
)

throttleGraph.update_layout(
    xaxis_range=[0, 14],
    autosize=False,
  
    xaxis=dict(
    showline=False,
    showticklabels=False,
    showgrid=False),

    yaxis=dict(
        showline=False,
        showticklabels=False,
        showgrid=False
    ),
    **graph_backgrounds,
)

throttleGraph.update_layout(xaxis_range=[0,17], 
                  autosize=False, 
                  **graph_backgrounds,)

# %%
import plotly.graph_objects as go
from codeassets import graph_config, graph_backgrounds, create_loading_figure

revgraph = go.Figure()

yaxis = [0] * 15
xaxis = list(range(1, 16))
size = [25] * 15

revgraph.add_trace(go.Scatter(
    x=xaxis,
    y=yaxis,
    mode='markers',
    marker=dict(size=size)
))



revgraph.update_layout(
    width=800,
    height=200,
    xaxis=dict(
        showline=False,
        showticklabels=False,
        showgrid=False,
        zeroline=False
    ),
    yaxis=dict(
        showline=False,
        showticklabels=False,
        showgrid=False,
        zeroline=False
    ),
    autosize=False,
    xaxis_range=[0, 17],
    **graph_backgrounds,
)

# %%
yaxis = [0] * 14

# %%
colors = [(235, 168, 61),
    (235, 64, 52),
    (61, 87, 235)]

c = list(colors[0])
c.append(80)
c
# Out:
# [235, 168, 61, 80]

# %%
-(100)
# Out:
# -100

# %%
from ctypes import LittleEndianStructure, Union, c_uint8, c_int8, c_uint16, c_int16, c_uint32, c_uint64, c_float, c_double, c_char

class TimeTrialDataSet(LittleEndianStructure):
    _pack_ = 1
    _fields_ = [
        ('m_carIdx', c_uint8),
        ('m_bestLapTime', c_float),
        ('m_sector1Time', c_float),
        ('m_sector2Time', c_float),
        ('m_sector3Time', c_float),
    ]

# %%
t = TimeTrialDataSet

field_names = [name for name, _ in t._fields_]

print(field_names)
# Out:
# ['m_carIdx', 'm_bestLapTime', 'm_sector1Time', 'm_sector2Time', 'm_sector3Time']

# %%
("Motion" : {
            "wheelSpeed": list(car.m_wheelSpeed),
            "wheelSlipRatio": list(car.m_wheelSlipRatio),
            "wheelSlipAngle": list(car.m_wheelSlipAngle),
        })
# Out:
#   Cell In[6], line 1
#     testdict.update('area' = {'stuff' : 0, 'others' : 1})
#                     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
testdict['area'] = {'stuff' : 0, 'others' : 1}

# %%
from codeassets import graph_config, graph_backgrounds, create_loading_figure

totalLapDistance = 20
player_distances = [-40, 0]
player_speeds = [180, 200]
rival_speeds = [200, 300]


fig = go.Figure()

fig.add_trace(go.Scatter(
x=player_distances,
y=player_speeds,
mode='lines',
name='Player',
line=dict(color='royalblue', width=4)
))

fig.add_trace(go.Scatter(
# x=rival_distances,
x=player_distances,
y=rival_speeds,
mode='lines',
name='Rival',
line=dict(color='firebrick', width=4)
))

# Dynamic y-axis for speed
max_speed = max(max(player_speeds, default=0), max(rival_speeds, default=0))

fig.update_layout(
title="Player vs Rival Speed Trace",
xaxis_title="Distance Around Lap (m)",
xaxis_range=[0,totalLapDistance],
yaxis_title="Speed (kph)",
yaxis_range=[0, max_speed + 20],
autosize=True, **graph_backgrounds,
    ),


fig

# %%
# Create random data with numpy
import numpy as np
np.random.seed(1)

N = 100
random_x = np.linspace(0, 1, N)
random_y0 = np.random.randn(N) + 5
random_y1 = np.random.randn(N)
random_y2 = np.random.randn(N) - 5

# Create traces
fig = go.Figure()

fig.add_trace(go.Scatter(x=random_x, y=random_y0,
                    mode='lines',
                    name='lines'))



fig.show()

# %%
# Example point
fig.add_scatter(x=[50], y=[10], marker=dict(size=[50]))

# Set axis ranges
fig.update_xaxes(range=[-100, 100])
fig.update_yaxes(range=[-100, 100])

# Move X-axis title closer to the negative end
fig.update_xaxes(
    title=dict(
        text="Steering",
        standoff=5,  # distance between axis and title
        font=dict(size=14)
    ),
    automargin=True,
    title_font=dict(size=16),
    title_standoff=0
)

# Move Y-axis title closer to the negative end
fig.update_yaxes(
    title=dict(
        text="Acceleration",
        standoff=5,
        font=dict(size=14)
    ),
    automargin=True,
    title_font=dict(size=16),
    title_standoff=0
)

fig.show()

# %%
data =  {'Telemetry': 0}
            # {'m_header' : 0, 
            # 'm_carTelemetryData' : [{'m_speed' : 10,
            #                         'm_throttle' : 0.5,
            #                         'm_steer' : 0,
            #                         'm_brake' :  0.5,
            #                         'm_clutch' :  0}], 
            # 'm_mfdPanelIndex' : 0, 
            # 'm_mfdPanelIndexSecondaryPlayer' : 0, 
            # 'm_suggestedGear' : 0}}

# %%
# data.get('Telemetry', {}).get('m_carTelemetryData', {})[0].get('m_brake')


data.get('Telemetry')
# Out:
# 0
